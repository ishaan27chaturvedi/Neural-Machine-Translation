# %% [markdown]
# <a href="https://colab.research.google.com/github/ishaan27chaturvedi/Neural-Machine-Translation/blob/main/7001_2021_22_Lab5_6_NeuralMachineTranslation_studentEdition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Lab 5 and 6: Neural Machine Translation (Extra Guide)**

# %% [markdown]
# This week and the next, we'll be build a neural machine translation model based on the sequence-to-sequence (seq2seq) models proposed by Sutskever et al., 2014 and Cho et al., 2014. The seq2seq model is widely used in machine translation systems such as Google’s neural machine translation system (GNMT) (Wu et al., 2016).
#
# A folder, **nmt_lab_files** has been provided for you. This folder contains 3 files:
# 1. **data.30.vi** - a file. each line of the file contains a Vietnamese sentence to be translated (i.e. the source sentences)
# 2. **data.30.en** - a file. each line of the file contains an English sentence corresponding to the Vietnamese sentence in the same line position. (i.e. the target sentences)
# 3. **nmt_model_keras.py** - the incomplete code for this lab.
#
# The doc file provided contains an explanation of the code file and a guide on how to complete the code (by doing 3 tasks). Read the doc file and if you can, complete the code as instructed. When the code is completed, skip to section xx of this notebook.
#
# This notebook (prior to section section xx) merely contains further explanation on sections of the code.

# %% [markdown]
# ##**LanguageDict**
#
# LanguageDict is a class for creating language dict objects.

# %% [markdown]
# ##**The <load_dataset()> Method**
#
# This helper method reads from the source and target files to
# - load max_num_examples sentences,
# - split the sentences them into train, development and testing, and
# - return relevant data.
# The code for this is fully commented.
#
# <br>
#
# As an example to the kind of ouput returned by this model, let's assume we are translating the sentence 'I like dogs' from English to English (this of course is never the case), such that the tokenized and case normalized source sentence list and target sentence list are as follows:
#
#
# ```
# # In our case this would actually be [['tôi', 'thích', 'thỏ']], i.e the Vietnamese equivalent of the English sentence.
# # We've used English to English here so we can follow along with the code.
# source_words = [['i', 'like', 'rabbits']]
# target_words = [['i', 'like', 'rabbits']]
# ```
# The word2ids for the source and target language dictionaries would look something like:
# ```
# source_dict.word2ids = {'<PAD>': 0, '<UNK>': 1, 'i': 2, 'like': 3, 'rabbits':4}
#
# # end and start tokens are added for the target words
# target_dict.word2ids = {'<PAD>': 0, '<UNK>': 1, '<start>': 2, 'i': 3, 'like': 4, 'rabbits':5, '<end>':6}
#
# ```
# Let's also assume that we are training and testing on this same dataset of one sentence.
# The **source words** for train/dev/test will be given as
# ```
# # a batch_size X max_sent_length array.
# source_words_train = [[2,3,4]] # corresponding to ['i', 'like', 'rabbits']
# source_words_dev = [[2,3,4]]  # corresponding to ['i', 'like', 'rabbits']
# source_words_test = [[2,3,4]] # corresponding to ['i', 'like', 'rabbits']
# ```
#
# The **target words** for train data will be given as follows (dev/test don't need target words as the model will provide this):
# ```
# target_words_train = [[2,3,4,5]] # corresponding to ['<start>', 'i', 'like', 'rabbits']
# ```
#
# The **target words labels** for each word will be the word after it. The target word labels for train/dev/test data will be given as follows
# ```
# target_words_train_labels = [[3,4,5,6]] # corresponding to ['i', 'like', 'rabbits', '<end>']
# target_words_dev_labels = [[3,4,5,6]] # corresponding to ['i', 'like', 'rabbits', '<end>']
# target_words_test_labels = [[3,4,5,6]] # corresponding to ['i', 'like', 'rabbits', '<end>']
# ```
# The dimensions for train target words labels would be expanded to this:
# `[[3], [4], [5], [6]]`

# %% [markdown]
# ##**The Neural Translation Model (NMT)**
#
# For the NMT the network (a system of connected layers/models) used for training differs slightly from the network used for inference. Both use the the seq-to-seq encoder-decoder architecture.

# %% [markdown]
# ###**The training mode**
#
# **Encoder**
#
# Given:
# - `source_words`: a `batch_size(num_sents) x max_sentence_length` array representing the source words. In our mini example, this would be the Vietnamese equivalent of `['i', 'like', 'rabbits']`; `[['tôi', 'thích', 'thỏ']]`
#
# The following steps comprise the encoding network:
#
# 1. transform `source_words` into `source_words_embeddings` using a randomly initialized embedding lookup. source_words_embeddings is thus a `batch_size(num_sents) x max_sentence_length x embedding_dim` array.
# 2. Apply embedding dropout of `embedding_dropout_rate`.
# 3. Use a single `LSTM` with `hidden_size` units to learn a representation for the source words i.e. to encode the input.
#
#     (a.) The hidden and cell states for this `LSTM` are initialized to zeros (i.e. we leave the `initial_states = None` default as is).
#
#     (b.) We save the `encoder_output` (the sequence not just the last state); and the encoder (hidden and cell) states.
#
# This way, the model encodes a representation for the source words. Task 1 guides you to complete the encoder part of the training model.
#
# <br>
#
# **Decoder (No Attention)**
#
# Given:
# - `target_words`: a `batch_size(i.e.num_sents in batch) x max_sentence_length+1` array representing the target words. This is a time shifted translation of the source words with an added (prepended) `<START>` token `['<start>', 'i', 'like', 'rabbits']`.
#
# The decoding is in the following steps:
#
# 1. transform `target_words` into `target_words_embeddings` using a randomly initialized embedding lookup. target_words_embeddings is thus a `batch_size x max_sentence_length+1 x embedding_dim` array.
#
# 2.  Apply embedding dropout of `embedding_dropout_rate`.
#
# 3. Use a single `LSTM` with `hidden_size` units to learn a representation for the target words. Some context is given to this model by using the encoder states to initialize the decoder lstm. This way the encoder state for `'tôi'` for example is used to learn to the representation (and next word prediction, see number 4.) for the `'<start>'` token, and so on.
#
# 4. For each token representation, use a dense layer to predict a `target_vocab_size` vector which is the probability that any given word in the target vocabulary is the next word following the represented token. The output `decoder_outputs_train` is thus a `batch_size x max_sent_length x target_vocab_size` array.

# %% [markdown]
# ###**The Inference Mode**
#
# **Encoder**
#
# The inference time encoding follows the same steps as training time encoding.
#
# <br>
#
# **Decoder (No attention)**
#
# During training time, we passed a `batch_size(num_sents) x max_sentence_length` array representing the target words into the decoder lstm. The decoder_lstm learns how to represent a given target sentence using the context from the encoder lstm (that learns to represent a source sentence).
#
# At test time, several things are different:
#
# 1. We no longer have access to a complete translation of the source sentence (recall that no target_words array exists for dev and test sets). Rather, we initialize the target_words_array as thus:
#
#     Each expected sentence contains only a single token index, the index of the `'<start>'` token. So, the target_word_dev/test is a `batch_size x 1` array. (see the nmt.eval() function for this)
#
# 2. This `batch_size x 1` array is fed to the trained decoder_lstm and the predicted array is a `batch_size x 1 x target_vocab_size` such that taking the argmax of this array accross the dimension 2 will give the most probable next word.
#
#     For example, at time_step `0`, the first time step, where the `step_target_words` given is the `batch_size x 1` array containing the `'<start>'` token, the next word prediction of the decoder is for each sentence (in the batch) the initial word in the sentence.
#
# 3. At the first time step, the decoder_lstm still uses the encoder_states as it's initial states. At subsequent time steps, it uses it's own states from the previous time steps. This is also what the decoder_lstm does at training time but it is made more explicit here as we loop over time steps using a for loop.
# (see nmt.eval())

# %% [markdown]
# ##**Training Without Attention**
#
# If you've completed Tasks 1 and 2, you are ready to train the NMT model without attention.
#
# Run the following cells to train the model for 10 epochs. It also shows the model summary of the each model you encapsulated.
#
# If you're using a GPU, training will no more than 10 minutes and you will get a BLEU score between 4 and 5.

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# change this to the path to your folder. Remember to start from the home directory
PATH = 'MyDrive/NMT/'

# %%
PATH_TO_FOLDER = "/content/drive/" + PATH

# %%
import sys
sys.path.append(PATH_TO_FOLDER)

# %%
SOURCE_PATH = 'data.30.vi'
TARGET_PATH = 'data.30.en'

# %%
cd '/content/drive/MyDrive/Colab Notebooks/NN NLP/NMT'
# Out:
# /content/drive/MyDrive/Colab Notebooks/NN NLP/NMT

# %%
import nmt_model_keras as nmt

# %%
nmt.main(SOURCE_PATH, TARGET_PATH, use_attention=False)
# Out:
# loading dictionaries
# read 24000/3000/3000 train/dev/test batches
# number of tokens in source: 2034, number of tokens in target:2506
# Task 1(a): Creating the embedding lookups...
#
# Task 1(b): Looking up source and target words...
#
# Task 1(c): Creating an encoder
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 						 Train Model Summary.
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, None)]       0           []
#
#  input_2 (InputLayer)           [(None, None)]       0           []
#
#  embedding (Embedding)          (None, None, 100)    203400      ['input_1[0][0]']
#
#  embedding_1 (Embedding)        (None, None, 100)    250600      ['input_2[0][0]']
#
#  dropout (Dropout)              (None, None, 100)    0           ['embedding[0][0]']
#
#  dropout_1 (Dropout)            (None, None, 100)    0           ['embedding_1[0][0]']
#
#  lstm (LSTM)                    [(None, None, 200),  240800      ['dropout[0][0]']
#                                  (None, 200),
#                                  (None, 200)]
#
#  lstm_1 (LSTM)                  [(None, None, 200),  240800      ['dropout_1[0][0]',
#                                  (None, 200),                     'lstm[0][1]',
#                                  (None, 200)]                     'lstm[0][2]']
#
#  dense (Dense)                  (None, None, 2506)   503706      ['lstm_1[0][0]']
#
# ==================================================================================================
# Total params: 1,439,306
# Trainable params: 1,439,306
# Non-trainable params: 0
# __________________________________________________________________________________________________
# 						 Inference Time Encoder Model Summary.
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, None)]            0
#
#  embedding (Embedding)       (None, None, 100)         203400
#
#  dropout (Dropout)           (None, None, 100)         0
#
#  lstm (LSTM)                 [(None, None, 200),       240800
#                               (None, 200),
#                               (None, 200)]
#
# =================================================================
# Total params: 444,200
# Trainable params: 444,200
# Non-trainable params: 0
# _________________________________________________________________
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
#  Putting together the decoder states
# 						 Decoder Inference Model summary
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, None)]       0           []
#
#  embedding_1 (Embedding)        (None, None, 100)    250600      ['input_2[0][0]']
#
#  dropout_1 (Dropout)            (None, None, 100)    0           ['embedding_1[0][0]']
#
#  input_3 (InputLayer)           [(None, 200)]        0           []
#
#  input_4 (InputLayer)           [(None, 200)]        0           []
#
#  lstm_1 (LSTM)                  [(None, None, 200),  240800      ['dropout_1[0][0]',
#                                  (None, 200),                     'input_3[0][0]',
#                                  (None, 200)]                     'input_4[0][0]']
#
#  input_5 (InputLayer)           [(None, None, 200)]  0           []
#
#  dense (Dense)                  (None, None, 2506)   503706      ['lstm_1[1][0]']
#
# ==================================================================================================
# Total params: 995,106
# Trainable params: 995,106
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Starting training epoch 1/20
# 240/240 [==============================] - 29s 96ms/step - loss: 2.1303 - accuracy: 0.2441
# Time used for epoch 1: 0 m 44 s
# Evaluating on dev set after epoch 1/20:
# Model BLEU score: 1.39
# 0 .
# Sample Output: [['there', 'are', 'four', '<unk>', '<unk>', 'that', ',', 'each', 'time', 'this', 'ring', '<unk>', 'it', ',', 'as', 'it', '<unk>', 'the', '<unk>', 'of', 'the', 'display', ',', 'it', '<unk>', 'up', 'a', 'position', 'signal', '.']]
# Predicted Output: ['and', 'i', '&apos;m', 'going', 'to', 'be', '<unk>', ',', 'and', 'i', '&apos;m', 'going', 'to', 'be', '<unk>', ',', 'and', 'i', '&apos;m', 'going', 'to', 'be', '<unk>', '.']
# 1 .
# Sample Output: [['but', 'this', 'is', 'really', 'just', 'the', 'beginning', '.']]
# Predicted Output: ['it', '&apos;s', 'a', '<unk>', '<unk>', '.']
# 2 .
# Sample Output: [['it', '<unk>', 'this', 'by', '<unk>', '<unk>', 'about', 'two', '<unk>', '.']]
# Predicted Output: ['and', 'i', '&apos;m', 'going', 'to', 'be', '<unk>', '.']
# 3 .
# Sample Output: [['so', 'as', 'you', 'can', 'see', 'here', ',', 'this', 'is', 'a', ',', '<unk>', '<unk>', '<unk>', 'board', '.']]
# Predicted Output: ['and', 'i', '&apos;m', 'going', 'to', 'be', '<unk>', ',', 'and', 'i', '&apos;m', 'going', 'to', 'be', '<unk>', '.']
# 4 .
# Sample Output: [['these', 'blocks', '<unk>', '<unk>', '.']]
# Predicted Output: ['it', '&apos;s', 'a', '<unk>', '.']
# Time used for evaluate on dev set: 0 m 8 s
# Starting training epoch 2/20
# 240/240 [==============================] - 24s 100ms/step - loss: 1.8303 - accuracy: 0.3017
# Time used for epoch 2: 0 m 24 s
# Evaluating on dev set after epoch 2/20:
# Model BLEU score: 2.73
# 0 .
# Sample Output: [['there', 'are', 'four', '<unk>', '<unk>', 'that', ',', 'each', 'time', 'this', 'ring', '<unk>', 'it', ',', 'as', 'it', '<unk>', 'the', '<unk>', 'of', 'the', 'display', ',', 'it', '<unk>', 'up', 'a', 'position', 'signal', '.']]
# Predicted Output: ['it', '&apos;s', 'a', '<unk>', '<unk>', ',', 'and', 'the', '<unk>', '<unk>', ',', '<unk>', '<unk>', ',', '<unk>', '<unk>', '<unk>', '.']
# 1 .
# Sample Output: [['but', 'this', 'is', 'really', 'just', 'the', 'beginning', '.']]
# Predicted Output: ['but', 'we', '&apos;re', 'going', 'to', 'do', '.']
# 2 .
# Sample Output: [['it', '<unk>', 'this', 'by', '<unk>', '<unk>', 'about', 'two', '<unk>', '.']]
# Predicted Output: ['and', 'the', '<unk>', '<unk>', ',', '<unk>', '<unk>', '.']
# 3 .
# Sample Output: [['so', 'as', 'you', 'can', 'see', 'here', ',', 'this', 'is', 'a', ',', '<unk>', '<unk>', '<unk>', 'board', '.']]
# Predicted Output: ['and', 'i', '&apos;m', 'going', 'to', 'be', 'a', '<unk>', '<unk>', ',', 'and', 'i', '&apos;m', 'going', 'to', 'be', '<unk>', '.']
# 4 .
# Sample Output: [['these', 'blocks', '<unk>', '<unk>', '.']]
# Predicted Output: ['it', '&apos;s', 'not', '.']
# Time used for evaluate on dev set: 0 m 7 s
# Starting training epoch 3/20
# 240/240 [==============================] - 24s 100ms/step - loss: 1.7164 - accuracy: 0.3319
# Time used for epoch 3: 0 m 24 s
# Evaluating on dev set after epoch 3/20:
# Model BLEU score: 2.95
# 0 .
# Sample Output: [['there', 'are', 'four', '<unk>', '<unk>', 'that', ',', 'each', 'time', 'this', 'ring', '<unk>', 'it', ',', 'as', 'it', '<unk>', 'the', '<unk>', 'of', 'the', 'display', ',', 'it', '<unk>', 'up', 'a', 'position', 'signal', '.']]
# Predicted Output: ['it', '&apos;s', 'a', '<unk>', '<unk>', ',', 'and', 'i', '&apos;m', 'going', 'to', 'be', '<unk>', ',', 'and', 'i', '&apos;m', 'going', 'to', 'be', '<unk>', '.']
# 1 .
# Sample Output: [['but', 'this', 'is', 'really', 'just', 'the', 'beginning', '.']]
# Predicted Output: ['but', 'it', '&apos;s', 'a', '<unk>', '.']
# 2 .
# Sample Output: [['it', '<unk>', 'this', 'by', '<unk>', '<unk>', 'about', 'two', '<unk>', '.']]
# Predicted Output: ['<unk>', '<unk>', ':', '<unk>', ',', '<unk>', '.']
# 3 .
# Sample Output: [['so', 'as', 'you', 'can', 'see', 'here', ',', 'this', 'is', 'a', ',', '<unk>', '<unk>', '<unk>', 'board', '.']]
# Predicted Output: ['and', 'the', '<unk>', 'is', '<unk>', ',', 'and', 'i', '&apos;m', 'going', 'to', 'be', '<unk>', '.']
# 4 .
# Sample Output: [['these', 'blocks', '<unk>', '<unk>', '.']]
# Predicted Output: ['this', 'is', 'a', '<unk>', '.']
# Time used for evaluate on dev set: 0 m 7 s
# Starting training epoch 4/20
# 240/240 [==============================] - 24s 99ms/step - loss: 1.6406 - accuracy: 0.3501
# Time used for epoch 4: 0 m 23 s
# Evaluating on dev set after epoch 4/20:
# Model BLEU score: 3.33
# 0 .
# Sample Output: [['there', 'are', 'four', '<unk>', '<unk>', 'that', ',', 'each', 'time', 'this', 'ring', '<unk>', 'it', ',', 'as', 'it', '<unk>', 'the', '<unk>', 'of', 'the', 'display', ',', 'it', '<unk>', 'up', 'a', 'position', 'signal', '.']]
# Predicted Output: ['there', 'are', '<unk>', '<unk>', ',', 'and', 'it', '&apos;s', 'a', '<unk>', '<unk>', '<unk>', ',', 'and', 'it', '&apos;s', '<unk>', '.']
# 1 .
# Sample Output: [['but', 'this', 'is', 'really', 'just', 'the', 'beginning', '.']]
# Predicted Output: ['but', 'the', '<unk>', 'is', '<unk>', '.']
# 2 .
# Sample Output: [['it', '<unk>', 'this', 'by', '<unk>', '<unk>', 'about', 'two', '<unk>', '.']]
# Predicted Output: ['<unk>', '<unk>', ':', 'the', '<unk>', '<unk>', '<unk>', '.']
# 3 .
# Sample Output: [['so', 'as', 'you', 'can', 'see', 'here', ',', 'this', 'is', 'a', ',', '<unk>', '<unk>', '<unk>', 'board', '.']]
# Predicted Output: ['and', 'it', '&apos;s', 'not', 'a', '<unk>', '<unk>', ',', 'and', 'it', '&apos;s', 'not', 'a', '<unk>', '.']
# 4 .
# Sample Output: [['these', 'blocks', '<unk>', '<unk>', '.']]
# Predicted Output: ['this', 'is', 'the', '<unk>', '.']
# Time used for evaluate on dev set: 0 m 7 s
# Starting training epoch 5/20
# 240/240 [==============================] - 24s 99ms/step - loss: 1.5870 - accuracy: 0.3613
# Time used for epoch 5: 0 m 41 s
# Evaluating on dev set after epoch 5/20:
# Model BLEU score: 4.12
# 0 .
# Sample Output: [['there', 'are', 'four', '<unk>', '<unk>', 'that', ',', 'each', 'time', 'this', 'ring', '<unk>', 'it', ',', 'as', 'it', '<unk>', 'the', '<unk>', 'of', 'the', 'display', ',', 'it', '<unk>', 'up', 'a', 'position', 'signal', '.']]
# Predicted Output: ['there', '&apos;s', 'a', '<unk>', '<unk>', ',', 'and', 'it', '&apos;s', 'a', '<unk>', '<unk>', ',', 'and', 'it', '&apos;s', 'a', '<unk>', '<unk>', 'of', '<unk>', '.']
# 1 .
# Sample Output: [['but', 'this', 'is', 'really', 'just', 'the', 'beginning', '.']]
# Predicted Output: ['but', 'there', '&apos;s', 'a', '<unk>', '<unk>', '.']
# 2 .
# Sample Output: [['it', '<unk>', 'this', 'by', '<unk>', '<unk>', 'about', 'two', '<unk>', '.']]
# Predicted Output: ['you', 'can', 'see', 'the', '<unk>', 'of', 'the', '<unk>', '.']
# 3 .
# Sample Output: [['so', 'as', 'you', 'can', 'see', 'here', ',', 'this', 'is', 'a', ',', '<unk>', '<unk>', '<unk>', 'board', '.']]
# Predicted Output: ['and', 'it', '&apos;s', 'not', 'a', '<unk>', '<unk>', ',', 'and', 'it', '&apos;s', 'a', '<unk>', '.']
# 4 .
# Sample Output: [['these', 'blocks', '<unk>', '<unk>', '.']]
# Predicted Output: ['this', 'is', 'a', '<unk>', '.']
# Time used for evaluate on dev set: 0 m 7 s
# Starting training epoch 6/20
# 240/240 [==============================] - 24s 101ms/step - loss: 1.5465 - accuracy: 0.3683
# Time used for epoch 6: 0 m 40 s
# Evaluating on dev set after epoch 6/20:
# Model BLEU score: 3.97
# 0 .
# Sample Output: [['there', 'are', 'four', '<unk>', '<unk>', 'that', ',', 'each', 'time', 'this', 'ring', '<unk>', 'it', ',', 'as', 'it', '<unk>', 'the', '<unk>', 'of', 'the', 'display', ',', 'it', '<unk>', 'up', 'a', 'position', 'signal', '.']]
# Predicted Output: ['there', '&apos;s', 'a', '<unk>', '<unk>', ',', 'and', 'the', '<unk>', '<unk>', '<unk>', '<unk>', '<unk>', ',', '<unk>', ',', '<unk>', ',', '<unk>', '.']
# 1 .
# Sample Output: [['but', 'this', 'is', 'really', 'just', 'the', 'beginning', '.']]
# Predicted Output: ['but', 'it', '&apos;s', 'not', 'a', 'lot', 'of', '<unk>', '.']
# 2 .
# Sample Output: [['it', '<unk>', 'this', 'by', '<unk>', '<unk>', 'about', 'two', '<unk>', '.']]
# Predicted Output: ['<unk>', '<unk>', ':', '<unk>', ',', '<unk>', '<unk>', '.']
# 3 .
# Sample Output: [['so', 'as', 'you', 'can', 'see', 'here', ',', 'this', 'is', 'a', ',', '<unk>', '<unk>', '<unk>', 'board', '.']]
# Predicted Output: ['and', 'you', 'can', 'see', 'the', '<unk>', 'of', 'the', '<unk>', 'of', 'the', '<unk>', '.']
# 4 .
# Sample Output: [['these', 'blocks', '<unk>', '<unk>', '.']]
# Predicted Output: ['this', 'is', '<unk>', '.']
# Time used for evaluate on dev set: 0 m 7 s
# Starting training epoch 7/20
# 240/240 [==============================] - 25s 104ms/step - loss: 1.5116 - accuracy: 0.3751
# Time used for epoch 7: 0 m 25 s
# Evaluating on dev set after epoch 7/20:
# Model BLEU score: 4.49
# 0 .
# Sample Output: [['there', 'are', 'four', '<unk>', '<unk>', 'that', ',', 'each', 'time', 'this', 'ring', '<unk>', 'it', ',', 'as', 'it', '<unk>', 'the', '<unk>', 'of', 'the', 'display', ',', 'it', '<unk>', 'up', 'a', 'position', 'signal', '.']]
# Predicted Output: ['there', '&apos;s', 'a', '<unk>', '<unk>', ',', 'and', 'it', '&apos;s', '<unk>', '<unk>', ',', 'and', 'it', '&apos;s', '<unk>', '<unk>', ',', 'and', '<unk>', '<unk>', '.']
# 1 .
# Sample Output: [['but', 'this', 'is', 'really', 'just', 'the', 'beginning', '.']]
# Predicted Output: ['but', 'it', '&apos;s', 'not', 'a', '<unk>', '.']
# 2 .
# Sample Output: [['it', '<unk>', 'this', 'by', '<unk>', '<unk>', 'about', 'two', '<unk>', '.']]
# Predicted Output: ['<unk>', '<unk>', ':', '<unk>', '<unk>', '<unk>', '.']
# 3 .
# Sample Output: [['so', 'as', 'you', 'can', 'see', 'here', ',', 'this', 'is', 'a', ',', '<unk>', '<unk>', '<unk>', 'board', '.']]
# Predicted Output: ['and', 'you', 'can', 'see', 'the', '<unk>', 'of', 'the', '<unk>', 'of', 'the', '<unk>', '.']
# 4 .
# Sample Output: [['these', 'blocks', '<unk>', '<unk>', '.']]
# Predicted Output: ['this', 'is', 'the', '<unk>', '.']
# Time used for evaluate on dev set: 0 m 7 s
# Starting training epoch 8/20
# 240/240 [==============================] - 25s 102ms/step - loss: 1.4837 - accuracy: 0.3787
# Time used for epoch 8: 0 m 24 s
# Evaluating on dev set after epoch 8/20:
# Model BLEU score: 4.48
# 0 .
# Sample Output: [['there', 'are', 'four', '<unk>', '<unk>', 'that', ',', 'each', 'time', 'this', 'ring', '<unk>', 'it', ',', 'as', 'it', '<unk>', 'the', '<unk>', 'of', 'the', 'display', ',', 'it', '<unk>', 'up', 'a', 'position', 'signal', '.']]
# Predicted Output: ['there', '&apos;s', 'a', '<unk>', '<unk>', '<unk>', ',', 'and', 'it', '&apos;s', '<unk>', ',', 'and', 'it', '&apos;s', '<unk>', '<unk>', 'in', 'the', '<unk>', '<unk>', '.']
# 1 .
# Sample Output: [['but', 'this', 'is', 'really', 'just', 'the', 'beginning', '.']]
# Predicted Output: ['but', 'it', '&apos;s', 'not', 'a', '<unk>', '.']
# 2 .
# Sample Output: [['it', '<unk>', 'this', 'by', '<unk>', '<unk>', 'about', 'two', '<unk>', '.']]
# Predicted Output: ['<unk>', '<unk>', ':', '<unk>', '<unk>', '<unk>', '.']
# 3 .
# Sample Output: [['so', 'as', 'you', 'can', 'see', 'here', ',', 'this', 'is', 'a', ',', '<unk>', '<unk>', '<unk>', 'board', '.']]
# Predicted Output: ['and', 'you', 'can', 'see', 'the', '<unk>', '<unk>', ',', 'and', 'it', '&apos;s', '<unk>', '.']
# 4 .
# Sample Output: [['these', 'blocks', '<unk>', '<unk>', '.']]
# Predicted Output: ['this', 'is', '<unk>', '.']
# Time used for evaluate on dev set: 0 m 7 s
# Starting training epoch 9/20
# 240/240 [==============================] - 24s 101ms/step - loss: 1.4603 - accuracy: 0.3825
# Time used for epoch 9: 0 m 40 s
# Evaluating on dev set after epoch 9/20:
# Model BLEU score: 4.61
# 0 .
# Sample Output: [['there', 'are', 'four', '<unk>', '<unk>', 'that', ',', 'each', 'time', 'this', 'ring', '<unk>', 'it', ',', 'as', 'it', '<unk>', 'the', '<unk>', 'of', 'the', 'display', ',', 'it', '<unk>', 'up', 'a', 'position', 'signal', '.']]
# Predicted Output: ['there', 'are', 'many', 'countries', 'in', 'the', '<unk>', ',', 'and', 'the', '<unk>', '<unk>', '<unk>', ',', 'and', 'the', '<unk>', '<unk>', '<unk>', '.']
# 1 .
# Sample Output: [['but', 'this', 'is', 'really', 'just', 'the', 'beginning', '.']]
# Predicted Output: ['but', 'here', '&apos;s', 'what', 'the', '<unk>', 'is', '.']
# 2 .
# Sample Output: [['it', '<unk>', 'this', 'by', '<unk>', '<unk>', 'about', 'two', '<unk>', '.']]
# Predicted Output: ['the', '<unk>', '<unk>', '<unk>', '<unk>', '.']
# 3 .
# Sample Output: [['so', 'as', 'you', 'can', 'see', 'here', ',', 'this', 'is', 'a', ',', '<unk>', '<unk>', '<unk>', 'board', '.']]
# Predicted Output: ['and', 'you', 'can', 'see', 'the', '<unk>', 'of', 'the', '<unk>', 'of', 'the', '<unk>', '.']
# 4 .
# Sample Output: [['these', 'blocks', '<unk>', '<unk>', '.']]
# Predicted Output: ['this', 'is', 'a', '<unk>', '.']
# Time used for evaluate on dev set: 0 m 7 s
# Starting training epoch 10/20
# 240/240 [==============================] - 24s 98ms/step - loss: 1.4405 - accuracy: 0.3857
# Time used for epoch 10: 0 m 40 s
# Evaluating on dev set after epoch 10/20:
# Model BLEU score: 4.75
# 0 .
# Sample Output: [['there', 'are', 'four', '<unk>', '<unk>', 'that', ',', 'each', 'time', 'this', 'ring', '<unk>', 'it', ',', 'as', 'it', '<unk>', 'the', '<unk>', 'of', 'the', 'display', ',', 'it', '<unk>', 'up', 'a', 'position', 'signal', '.']]
# Predicted Output: ['there', 'are', 'many', '<unk>', 'in', 'the', '<unk>', '<unk>', ',', 'and', 'the', '<unk>', '<unk>', ',', 'the', '<unk>', '<unk>', 'of', 'the', '<unk>', '<unk>', '.']
# 1 .
# Sample Output: [['but', 'this', 'is', 'really', 'just', 'the', 'beginning', '.']]
# Predicted Output: ['but', 'there', '&apos;s', 'no', '<unk>', '.']
# 2 .
# Sample Output: [['it', '<unk>', 'this', 'by', '<unk>', '<unk>', 'about', 'two', '<unk>', '.']]
# Predicted Output: ['<unk>', '<unk>', ':', '<unk>', ',', '<unk>', '<unk>', '.']
# 3 .
# Sample Output: [['so', 'as', 'you', 'can', 'see', 'here', ',', 'this', 'is', 'a', ',', '<unk>', '<unk>', '<unk>', 'board', '.']]
# Predicted Output: ['and', 'he', 'decided', 'to', '<unk>', 'the', '<unk>', 'of', 'the', '<unk>', 'of', 'the', '<unk>', '.']
# 4 .
# Sample Output: [['these', 'blocks', '<unk>', '<unk>', '.']]
# Predicted Output: ['this', 'is', 'a', '<unk>', '.']
# Time used for evaluate on dev set: 0 m 7 s
# Starting training epoch 11/20
# 240/240 [==============================] - 24s 99ms/step - loss: 1.4235 - accuracy: 0.3885
# Time used for epoch 11: 0 m 23 s
# Evaluating on dev set after epoch 11/20:
# Model BLEU score: 4.95
# 0 .
# Sample Output: [['there', 'are', 'four', '<unk>', '<unk>', 'that', ',', 'each', 'time', 'this', 'ring', '<unk>', 'it', ',', 'as', 'it', '<unk>', 'the', '<unk>', 'of', 'the', 'display', ',', 'it', '<unk>', 'up', 'a', 'position', 'signal', '.']]
# Predicted Output: ['there', 'are', 'many', '<unk>', ',', 'and', 'the', '<unk>', 'of', 'the', '<unk>', '<unk>', ',', 'the', '<unk>', 'of', 'the', '<unk>', '<unk>', '.']
# 1 .
# Sample Output: [['but', 'this', 'is', 'really', 'just', 'the', 'beginning', '.']]
# Predicted Output: ['but', 'the', 'reason', 'is', 'that', 'it', '&apos;s', 'not', '<unk>', '.']
# 2 .
# Sample Output: [['it', '<unk>', 'this', 'by', '<unk>', '<unk>', 'about', 'two', '<unk>', '.']]
# Predicted Output: ['<unk>', '<unk>', ':', '<unk>', '<unk>', '.']
# 3 .
# Sample Output: [['so', 'as', 'you', 'can', 'see', 'here', ',', 'this', 'is', 'a', ',', '<unk>', '<unk>', '<unk>', 'board', '.']]
# Predicted Output: ['and', 'as', 'you', 'see', ',', 'the', '<unk>', 'of', 'the', '<unk>', 'is', '<unk>', '.']
# 4 .
# Sample Output: [['these', 'blocks', '<unk>', '<unk>', '.']]
# Predicted Output: ['this', 'is', 'the', '<unk>', '.']
# Time used for evaluate on dev set: 0 m 7 s
# Starting training epoch 12/20
# 240/240 [==============================] - 24s 100ms/step - loss: 1.4089 - accuracy: 0.3908
# Time used for epoch 12: 0 m 40 s
# Evaluating on dev set after epoch 12/20:
# Model BLEU score: 4.80
# 0 .
# Sample Output: [['there', 'are', 'four', '<unk>', '<unk>', 'that', ',', 'each', 'time', 'this', 'ring', '<unk>', 'it', ',', 'as', 'it', '<unk>', 'the', '<unk>', 'of', 'the', 'display', ',', 'it', '<unk>', 'up', 'a', 'position', 'signal', '.']]
# Predicted Output: ['there', 'are', '<unk>', '<unk>', '<unk>', ',', 'and', 'it', '&apos;s', '<unk>', ',', 'and', 'it', '&apos;s', '<unk>', '<unk>', ',', '<unk>', ',', '<unk>', '.']
# 1 .
# Sample Output: [['but', 'this', 'is', 'really', 'just', 'the', 'beginning', '.']]
# Predicted Output: ['but', 'it', '&apos;s', 'not', 'a', '<unk>', '.']
# 2 .
# Sample Output: [['it', '<unk>', 'this', 'by', '<unk>', '<unk>', 'about', 'two', '<unk>', '.']]
# Predicted Output: ['<unk>', '<unk>', ':', '<unk>', '<unk>', '<unk>', '.']
# 3 .
# Sample Output: [['so', 'as', 'you', 'can', 'see', 'here', ',', 'this', 'is', 'a', ',', '<unk>', '<unk>', '<unk>', 'board', '.']]
# Predicted Output: ['and', 'you', 'can', 'see', 'the', '<unk>', 'of', 'the', '<unk>', '<unk>', '.']
# 4 .
# Sample Output: [['these', 'blocks', '<unk>', '<unk>', '.']]
# Predicted Output: ['this', 'is', '<unk>', '.']
# Time used for evaluate on dev set: 0 m 7 s
# Starting training epoch 13/20
# 240/240 [==============================] - 24s 100ms/step - loss: 1.3941 - accuracy: 0.3935
# Time used for epoch 13: 0 m 40 s
# Evaluating on dev set after epoch 13/20:
# Model BLEU score: 5.11
# 0 .
# Sample Output: [['there', 'are', 'four', '<unk>', '<unk>', 'that', ',', 'each', 'time', 'this', 'ring', '<unk>', 'it', ',', 'as', 'it', '<unk>', 'the', '<unk>', 'of', 'the', 'display', ',', 'it', '<unk>', 'up', 'a', 'position', 'signal', '.']]
# Predicted Output: ['there', 'are', 'many', '<unk>', '<unk>', '<unk>', ',', 'and', 'the', '<unk>', ',', 'the', '<unk>', ',', '<unk>', ',', '<unk>', ',', '<unk>', '.']
# 1 .
# Sample Output: [['but', 'this', 'is', 'really', 'just', 'the', 'beginning', '.']]
# Predicted Output: ['but', 'it', '&apos;s', 'not', 'a', '<unk>', '.']
# 2 .
# Sample Output: [['it', '<unk>', 'this', 'by', '<unk>', '<unk>', 'about', 'two', '<unk>', '.']]
# Predicted Output: ['the', '<unk>', '<unk>', '<unk>', '<unk>', '.']
# 3 .
# Sample Output: [['so', 'as', 'you', 'can', 'see', 'here', ',', 'this', 'is', 'a', ',', '<unk>', '<unk>', '<unk>', 'board', '.']]
# Predicted Output: ['and', 'you', 'can', 'see', 'the', '<unk>', ',', 'and', 'the', '<unk>', 'of', 'the', '<unk>', '.']
# 4 .
# Sample Output: [['these', 'blocks', '<unk>', '<unk>', '.']]
# Predicted Output: ['this', 'is', '<unk>', '.']
# Time used for evaluate on dev set: 0 m 7 s
# Starting training epoch 14/20
# 240/240 [==============================] - 26s 108ms/step - loss: 1.3837 - accuracy: 0.3940
# Time used for epoch 14: 0 m 41 s
# Evaluating on dev set after epoch 14/20:
# Model BLEU score: 4.97
# 0 .
# Sample Output: [['there', 'are', 'four', '<unk>', '<unk>', 'that', ',', 'each', 'time', 'this', 'ring', '<unk>', 'it', ',', 'as', 'it', '<unk>', 'the', '<unk>', 'of', 'the', 'display', ',', 'it', '<unk>', 'up', 'a', 'position', 'signal', '.']]
# Predicted Output: ['there', '&apos;s', 'a', 'lot', 'of', '<unk>', '<unk>', '<unk>', ',', 'and', 'it', '&apos;s', '<unk>', ',', 'and', 'the', '<unk>', '<unk>', '<unk>', '.']
# 1 .
# Sample Output: [['but', 'this', 'is', 'really', 'just', 'the', 'beginning', '.']]
# Predicted Output: ['but', 'that', '&apos;s', 'the', '<unk>', '.']
# 2 .
# Sample Output: [['it', '<unk>', 'this', 'by', '<unk>', '<unk>', 'about', 'two', '<unk>', '.']]
# Predicted Output: ['the', '<unk>', '<unk>', '<unk>', '<unk>', '.']
# 3 .
# Sample Output: [['so', 'as', 'you', 'can', 'see', 'here', ',', 'this', 'is', 'a', ',', '<unk>', '<unk>', '<unk>', 'board', '.']]
# Predicted Output: ['and', 'you', 'can', 'see', 'the', '<unk>', 'of', 'the', '<unk>', 'of', 'the', '<unk>', '.']
# 4 .
# Sample Output: [['these', 'blocks', '<unk>', '<unk>', '.']]
# Predicted Output: ['it', '&apos;s', '<unk>', '.']
# Time used for evaluate on dev set: 0 m 8 s
# Starting training epoch 15/20
# 240/240 [==============================] - 26s 107ms/step - loss: 1.3705 - accuracy: 0.3980
# Time used for epoch 15: 0 m 40 s
# Evaluating on dev set after epoch 15/20:
# Model BLEU score: 5.08
# 0 .
# Sample Output: [['there', 'are', 'four', '<unk>', '<unk>', 'that', ',', 'each', 'time', 'this', 'ring', '<unk>', 'it', ',', 'as', 'it', '<unk>', 'the', '<unk>', 'of', 'the', 'display', ',', 'it', '<unk>', 'up', 'a', 'position', 'signal', '.']]
# Predicted Output: ['there', '&apos;s', 'a', '<unk>', '<unk>', '<unk>', '<unk>', '<unk>', '<unk>', '<unk>', '<unk>', '<unk>', '<unk>', '<unk>', '<unk>', '.']
# 1 .
# Sample Output: [['but', 'this', 'is', 'really', 'just', 'the', 'beginning', '.']]
# Predicted Output: ['but', 'it', '&apos;s', 'not', 'a', '<unk>', '.']
# 2 .
# Sample Output: [['it', '<unk>', 'this', 'by', '<unk>', '<unk>', 'about', 'two', '<unk>', '.']]
# Predicted Output: ['the', '<unk>', '<unk>', '<unk>', '<unk>', '.']
# 3 .
# Sample Output: [['so', 'as', 'you', 'can', 'see', 'here', ',', 'this', 'is', 'a', ',', '<unk>', '<unk>', '<unk>', 'board', '.']]
# Predicted Output: ['and', 'you', 'can', 'see', 'the', '<unk>', '<unk>', ',', 'and', 'it', '&apos;s', '<unk>', '.']
# 4 .
# Sample Output: [['these', 'blocks', '<unk>', '<unk>', '.']]
# Predicted Output: ['it', '&apos;s', 'not', '<unk>', '.']
# Time used for evaluate on dev set: 0 m 7 s
# Starting training epoch 16/20
# 240/240 [==============================] - 26s 108ms/step - loss: 1.3625 - accuracy: 0.3986
# Time used for epoch 16: 0 m 25 s
# Evaluating on dev set after epoch 16/20:
# Model BLEU score: 5.45
# 0 .
# Sample Output: [['there', 'are', 'four', '<unk>', '<unk>', 'that', ',', 'each', 'time', 'this', 'ring', '<unk>', 'it', ',', 'as', 'it', '<unk>', 'the', '<unk>', 'of', 'the', 'display', ',', 'it', '<unk>', 'up', 'a', 'position', 'signal', '.']]
# Predicted Output: ['there', '&apos;s', 'a', '<unk>', '<unk>', '<unk>', ',', 'and', 'the', '<unk>', 'is', '<unk>', '<unk>', ',', 'and', 'the', '<unk>', '<unk>', '<unk>', '.']
# 1 .
# Sample Output: [['but', 'this', 'is', 'really', 'just', 'the', 'beginning', '.']]
# Predicted Output: ['but', 'it', '&apos;s', 'not', 'a', '<unk>', '.']
# 2 .
# Sample Output: [['it', '<unk>', 'this', 'by', '<unk>', '<unk>', 'about', 'two', '<unk>', '.']]
# Predicted Output: ['the', '<unk>', '<unk>', 'is', '<unk>', '<unk>', '.']
# 3 .
# Sample Output: [['so', 'as', 'you', 'can', 'see', 'here', ',', 'this', 'is', 'a', ',', '<unk>', '<unk>', '<unk>', 'board', '.']]
# Predicted Output: ['and', 'you', 'see', 'the', '<unk>', 'of', 'the', '<unk>', ',', 'and', 'the', '<unk>', 'is', '<unk>', '.']
# 4 .
# Sample Output: [['these', 'blocks', '<unk>', '<unk>', '.']]
# Predicted Output: ['this', 'is', '<unk>', '.']
# Time used for evaluate on dev set: 0 m 7 s
# Starting training epoch 17/20
# 240/240 [==============================] - 26s 106ms/step - loss: 1.3544 - accuracy: 0.3990
# Time used for epoch 17: 0 m 40 s
# Evaluating on dev set after epoch 17/20:
# Model BLEU score: 5.30
# 0 .
# Sample Output: [['there', 'are', 'four', '<unk>', '<unk>', 'that', ',', 'each', 'time', 'this', 'ring', '<unk>', 'it', ',', 'as', 'it', '<unk>', 'the', '<unk>', 'of', 'the', 'display', ',', 'it', '<unk>', 'up', 'a', 'position', 'signal', '.']]
# Predicted Output: ['there', 'are', 'many', 'countries', 'in', 'the', '<unk>', ',', 'and', 'the', '<unk>', ',', 'the', '<unk>', ',', 'the', '<unk>', ',', 'and', 'the', '<unk>', '<unk>', '.']
# 1 .
# Sample Output: [['but', 'this', 'is', 'really', 'just', 'the', 'beginning', '.']]
# Predicted Output: ['but', 'it', '&apos;s', 'not', 'a', '<unk>', '.']
# 2 .
# Sample Output: [['it', '<unk>', 'this', 'by', '<unk>', '<unk>', 'about', 'two', '<unk>', '.']]
# Predicted Output: ['and', '<unk>', '<unk>', '<unk>', ',', '<unk>', '.']
# 3 .
# Sample Output: [['so', 'as', 'you', 'can', 'see', 'here', ',', 'this', 'is', 'a', ',', '<unk>', '<unk>', '<unk>', 'board', '.']]
# Predicted Output: ['and', 'you', 'see', 'the', '<unk>', '<unk>', ',', 'and', 'the', '<unk>', 'is', '<unk>', '.']
# 4 .
# Sample Output: [['these', 'blocks', '<unk>', '<unk>', '.']]
# Predicted Output: ['this', 'is', '<unk>', '.']
# Time used for evaluate on dev set: 0 m 7 s
# Starting training epoch 18/20
# 240/240 [==============================] - 25s 105ms/step - loss: 1.3455 - accuracy: 0.4016
# Time used for epoch 18: 0 m 41 s
# Evaluating on dev set after epoch 18/20:
# Model BLEU score: 5.21
# 0 .
# Sample Output: [['there', 'are', 'four', '<unk>', '<unk>', 'that', ',', 'each', 'time', 'this', 'ring', '<unk>', 'it', ',', 'as', 'it', '<unk>', 'the', '<unk>', 'of', 'the', 'display', ',', 'it', '<unk>', 'up', 'a', 'position', 'signal', '.']]
# Predicted Output: ['there', '&apos;s', 'a', 'lot', 'of', '<unk>', '<unk>', ',', 'and', 'it', '&apos;s', 'a', '<unk>', '<unk>', ',', 'and', 'the', '<unk>', '<unk>', '<unk>', '.']
# 1 .
# Sample Output: [['but', 'this', 'is', 'really', 'just', 'the', 'beginning', '.']]
# Predicted Output: ['but', 'it', '&apos;s', 'not', 'a', '<unk>', '.']
# 2 .
# Sample Output: [['it', '<unk>', 'this', 'by', '<unk>', '<unk>', 'about', 'two', '<unk>', '.']]
# Predicted Output: ['and', '<unk>', ',', '<unk>', '<unk>', '.']
# 3 .
# Sample Output: [['so', 'as', 'you', 'can', 'see', 'here', ',', 'this', 'is', 'a', ',', '<unk>', '<unk>', '<unk>', 'board', '.']]
# Predicted Output: ['and', 'you', 'can', 'see', 'the', '<unk>', 'of', 'the', '<unk>', '<unk>', '<unk>', '.']
# 4 .
# Sample Output: [['these', 'blocks', '<unk>', '<unk>', '.']]
# Predicted Output: ['this', '<unk>', 'is', '<unk>', '.']
# Time used for evaluate on dev set: 0 m 7 s
# Starting training epoch 19/20
# 240/240 [==============================] - 26s 108ms/step - loss: 1.3382 - accuracy: 0.4015
# Time used for epoch 19: 0 m 26 s
# Evaluating on dev set after epoch 19/20:
# Model BLEU score: 5.27
# 0 .
# Sample Output: [['there', 'are', 'four', '<unk>', '<unk>', 'that', ',', 'each', 'time', 'this', 'ring', '<unk>', 'it', ',', 'as', 'it', '<unk>', 'the', '<unk>', 'of', 'the', 'display', ',', 'it', '<unk>', 'up', 'a', 'position', 'signal', '.']]
# Predicted Output: ['there', 'are', 'many', '<unk>', 'in', 'the', '<unk>', ',', 'and', 'the', '<unk>', '<unk>', 'club', 'helped', 'form', 'and', '<unk>', '<unk>', '.']
# 1 .
# Sample Output: [['but', 'this', 'is', 'really', 'just', 'the', 'beginning', '.']]
# Predicted Output: ['but', 'it', '&apos;s', 'not', 'a', '<unk>', '.']
# 2 .
# Sample Output: [['it', '<unk>', 'this', 'by', '<unk>', '<unk>', 'about', 'two', '<unk>', '.']]
# Predicted Output: ['and', '<unk>', '<unk>', '<unk>', '.']
# 3 .
# Sample Output: [['so', 'as', 'you', 'can', 'see', 'here', ',', 'this', 'is', 'a', ',', '<unk>', '<unk>', '<unk>', 'board', '.']]
# Predicted Output: ['and', 'you', 'can', 'see', 'the', '<unk>', 'of', 'the', '<unk>', '<unk>', ',', 'and', 'it', '&apos;s', '<unk>', '.']
# 4 .
# Sample Output: [['these', 'blocks', '<unk>', '<unk>', '.']]
# Predicted Output: ['this', 'is', '<unk>', '.']
# Time used for evaluate on dev set: 0 m 7 s
# Starting training epoch 20/20
# 240/240 [==============================] - 26s 108ms/step - loss: 1.3318 - accuracy: 0.4026
# Time used for epoch 20: 0 m 40 s
# Evaluating on dev set after epoch 20/20:
# Model BLEU score: 5.36
# 0 .
# Sample Output: [['there', 'are', 'four', '<unk>', '<unk>', 'that', ',', 'each', 'time', 'this', 'ring', '<unk>', 'it', ',', 'as', 'it', '<unk>', 'the', '<unk>', 'of', 'the', 'display', ',', 'it', '<unk>', 'up', 'a', 'position', 'signal', '.']]
# Predicted Output: ['there', '&apos;s', 'a', '<unk>', '<unk>', ',', 'and', 'the', '<unk>', '<unk>', ',', 'the', '<unk>', ',', 'the', '<unk>', '<unk>', '<unk>', '<unk>', '.']
# 1 .
# Sample Output: [['but', 'this', 'is', 'really', 'just', 'the', 'beginning', '.']]
# Predicted Output: ['but', 'it', '&apos;s', 'not', 'a', '<unk>', '.']
# 2 .
# Sample Output: [['it', '<unk>', 'this', 'by', '<unk>', '<unk>', 'about', 'two', '<unk>', '.']]
# Predicted Output: ['the', '<unk>', '<unk>', '<unk>', '<unk>', '.']
# 3 .
# Sample Output: [['so', 'as', 'you', 'can', 'see', 'here', ',', 'this', 'is', 'a', ',', '<unk>', '<unk>', '<unk>', 'board', '.']]
# Predicted Output: ['and', 'you', 'see', 'the', '<unk>', '<unk>', ',', 'and', 'the', '<unk>', '<unk>', '.']
# 4 .
# Sample Output: [['these', 'blocks', '<unk>', '<unk>', '.']]
# Predicted Output: ['this', 'is', '<unk>', '.']
# Time used for evaluate on dev set: 0 m 7 s
# Training finished!
# Time used for training: 14 m 3 s
# Evaluating on test set:
# Model BLEU score: 5.66
# 0 .
# Sample Output: [['the', 'second', 'quote', 'is', 'from', 'the', 'head', 'of', 'the', 'u.k.', 'financial', 'services', '<unk>', '.']]
# Predicted Output: ['the', '<unk>', 'of', 'the', '<unk>', '<unk>', '<unk>', '<unk>', '<unk>', '<unk>', ',', '<unk>', '<unk>', '.']
# 1 .
# Sample Output: [['it', 'gets', 'worse', '.']]
# Predicted Output: ['the', 'other', 'thing', 'that', 'transition', 'does', '.']
# 2 .
# Sample Output: [['what', '&apos;s', 'happening', 'here', '?', 'how', 'can', 'this', 'be', 'possible', '?']]
# Predicted Output: ['what', '&apos;s', 'going', 'on', ',', 'and', 'what', '&apos;s', 'going', 'on', '?', 'what', 'is', 'this', '?']
# 3 .
# Sample Output: [['unfortunately', ',', 'the', 'answer', 'is', 'yes', '.']]
# Predicted Output: ['no', ',', 'it', '&apos;s', 'not', 'a', '<unk>', '.']
# 4 .
# Sample Output: [['but', 'there', '&apos;s', 'an', '<unk>', 'solution', 'which', 'is', 'coming', 'from', 'what', 'is', 'known', 'as', 'the', 'science', 'of', '<unk>', '.']]
# Predicted Output: ['but', 'in', 'the', '<unk>', ',', 'it', '&apos;s', 'a', '<unk>', '<unk>', ',', 'and', 'it', '&apos;s', '<unk>', ',', 'and', 'it', '&apos;s', '<unk>', '.']
# Time used for evaluate on test set: 0 m 7 s

# %% [markdown]
# ##**Decoding with Attention**

# %% [markdown]
# The inputs to the attention layer are encoder and decoder outputs. The attention mechanism:
# 1. Computes a score (a luong score) for each source word
# 2. Weights the words by their luong scores.
# 3. Concatenates the wieghted encoder representation with the decoder_ouput.
# This new decoder output will now be the input to the decoder_dense layer.
#
# Task 3 description in the doc file outlines the steps for this in detail. Once you have completed this Task, you are now ready to train with attention. Training time will be no more than 10 minutes using a GPU and you should get a bleu score of about 15.

# %%
nmt.main(SOURCE_PATH, TARGET_PATH, use_attention=True)
# Out:
# loading dictionaries
# read 24000/3000/3000 train/dev/test batches
# number of tokens in source: 2034, number of tokens in target:2506
# Task 1(a): Creating the embedding lookups...
#
# Task 1(b): Looking up source and target words...
#
# Task 1(c): Creating an encoder
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 						 Train Model Summary.
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, None)]       0           []
#
#  embedding (Embedding)          (None, None, 100)    203400      ['input_1[0][0]']
#
#  input_2 (InputLayer)           [(None, None)]       0           []
#
#  dropout (Dropout)              (None, None, 100)    0           ['embedding[0][0]']
#
#  embedding_1 (Embedding)        (None, None, 100)    250600      ['input_2[0][0]']
#
#  lstm (LSTM)                    [(None, None, 200),  240800      ['dropout[0][0]']
#                                  (None, 200),
#                                  (None, 200)]
#
#  dropout_1 (Dropout)            (None, None, 100)    0           ['embedding_1[0][0]']
#
#  lstm_1 (LSTM)                  [(None, None, 200),  240800      ['dropout_1[0][0]',
#                                  (None, 200),                     'lstm[0][1]',
#                                  (None, 200)]                     'lstm[0][2]']
#
#  attention_layer (AttentionLaye  (None, None, 400)   0           ['lstm[0][0]',
#  r)                                                               'lstm_1[0][0]']
#
#  dense (Dense)                  (None, None, 2506)   1004906     ['attention_layer[0][0]']
#
# ==================================================================================================
# Total params: 1,940,506
# Trainable params: 1,940,506
# Non-trainable params: 0
# __________________________________________________________________________________________________
# 						 Inference Time Encoder Model Summary.
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, None)]            0
#
#  embedding (Embedding)       (None, None, 100)         203400
#
#  dropout (Dropout)           (None, None, 100)         0
#
#  lstm (LSTM)                 [(None, None, 200),       240800
#                               (None, 200),
#                               (None, 200)]
#
# =================================================================
# Total params: 444,200
# Trainable params: 444,200
# Non-trainable params: 0
# _________________________________________________________________
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
#  Putting together the decoder states
# 						 Decoder Inference Model summary
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, None)]       0           []
#
#  embedding_1 (Embedding)        (None, None, 100)    250600      ['input_2[0][0]']
#
#  dropout_1 (Dropout)            (None, None, 100)    0           ['embedding_1[0][0]']
#
#  input_3 (InputLayer)           [(None, 200)]        0           []
#
#  input_4 (InputLayer)           [(None, 200)]        0           []
#
#  input_5 (InputLayer)           [(None, None, 200)]  0           []
#
#  lstm_1 (LSTM)                  [(None, None, 200),  240800      ['dropout_1[0][0]',
#                                  (None, 200),                     'input_3[0][0]',
#                                  (None, 200)]                     'input_4[0][0]']
#
#  attention_layer_1 (AttentionLa  (None, None, 400)   0           ['input_5[0][0]',
#  yer)                                                             'lstm_1[1][0]']
#
#  dense (Dense)                  (None, None, 2506)   1004906     ['attention_layer_1[0][0]']
#
# ==================================================================================================
# Total params: 1,496,306
# Trainable params: 1,496,306
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Starting training epoch 1/10
# 240/240 [==============================] - 34s 116ms/step - loss: 2.0518 - accuracy: 0.2670
# Time used for epoch 1: 0 m 33 s
# Evaluating on dev set after epoch 1/10:
# Model BLEU score: 4.90
# 0 .
# Sample Output: [['there', 'are', 'four', '<unk>', '<unk>', 'that', ',', 'each', 'time', 'this', 'ring', '<unk>', 'it', ',', 'as', 'it', '<unk>', 'the', '<unk>', 'of', 'the', 'display', ',', 'it', '<unk>', 'up', 'a', 'position', 'signal', '.']]
# Predicted Output: ['they', '&apos;re', 'going', 'to', '<unk>', 'the', '<unk>', ',', '<unk>', ',', '<unk>', ',', '<unk>', ',', '<unk>', ',', '<unk>', '.']
# 1 .
# Sample Output: [['but', 'this', 'is', 'really', 'just', 'the', 'beginning', '.']]
# Predicted Output: ['but', 'it', '&apos;s', 'not', 'a', 'lot', 'of', '<unk>', '.']
# 2 .
# Sample Output: [['it', '<unk>', 'this', 'by', '<unk>', '<unk>', 'about', 'two', '<unk>', '.']]
# Predicted Output: ['the', '<unk>', 'of', '<unk>', '<unk>', '.']
# 3 .
# Sample Output: [['so', 'as', 'you', 'can', 'see', 'here', ',', 'this', 'is', 'a', ',', '<unk>', '<unk>', '<unk>', 'board', '.']]
# Predicted Output: ['and', 'there', '&apos;s', 'a', '<unk>', '<unk>', 'of', '<unk>', '<unk>', '<unk>', '.']
# 4 .
# Sample Output: [['these', 'blocks', '<unk>', '<unk>', '.']]
# Predicted Output: ['the', '<unk>', 'is', '<unk>', '.']
# Time used for evaluate on dev set: 0 m 8 s
# Starting training epoch 2/10
# 240/240 [==============================] - 28s 116ms/step - loss: 1.5688 - accuracy: 0.3995
# Time used for epoch 2: 0 m 27 s
# Evaluating on dev set after epoch 2/10:
# Model BLEU score: 10.55
# 0 .
# Sample Output: [['there', 'are', 'four', '<unk>', '<unk>', 'that', ',', 'each', 'time', 'this', 'ring', '<unk>', 'it', ',', 'as', 'it', '<unk>', 'the', '<unk>', 'of', 'the', 'display', ',', 'it', '<unk>', 'up', 'a', 'position', 'signal', '.']]
# Predicted Output: ['the', '<unk>', 'of', 'the', '<unk>', ',', '<unk>', ',', 'it', '&apos;s', '<unk>', ',', 'it', '&apos;s', '<unk>', '.']
# 1 .
# Sample Output: [['but', 'this', 'is', 'really', 'just', 'the', 'beginning', '.']]
# Predicted Output: ['but', 'this', 'is', 'really', 'really', '<unk>', '.']
# 2 .
# Sample Output: [['it', '<unk>', 'this', 'by', '<unk>', '<unk>', 'about', 'two', '<unk>', '.']]
# Predicted Output: ['the', '<unk>', '<unk>', '<unk>', '.']
# 3 .
# Sample Output: [['so', 'as', 'you', 'can', 'see', 'here', ',', 'this', 'is', 'a', ',', '<unk>', '<unk>', '<unk>', 'board', '.']]
# Predicted Output: ['and', 'you', 'can', 'see', 'here', '&apos;s', '<unk>', '<unk>', '<unk>', '.']
# 4 .
# Sample Output: [['these', 'blocks', '<unk>', '<unk>', '.']]
# Predicted Output: ['this', 'can', 'be', '<unk>', '.']
# Time used for evaluate on dev set: 0 m 7 s
# Starting training epoch 3/10
# 240/240 [==============================] - 28s 118ms/step - loss: 1.3162 - accuracy: 0.4547
# Time used for epoch 3: 0 m 28 s
# Evaluating on dev set after epoch 3/10:
# Model BLEU score: 12.65
# 0 .
# Sample Output: [['there', 'are', 'four', '<unk>', '<unk>', 'that', ',', 'each', 'time', 'this', 'ring', '<unk>', 'it', ',', 'as', 'it', '<unk>', 'the', '<unk>', 'of', 'the', 'display', ',', 'it', '<unk>', 'up', 'a', 'position', 'signal', '.']]
# Predicted Output: ['there', '&apos;s', 'four', '<unk>', ',', 'to', '<unk>', 'this', 'process', ',', 'but', 'it', 'was', 'about', 'this', '<unk>', ',', 'it', 'was', '<unk>', 'to', '<unk>', '.']
# 1 .
# Sample Output: [['but', 'this', 'is', 'really', 'just', 'the', 'beginning', '.']]
# Predicted Output: ['but', 'this', 'is', 'actually', '<unk>', '.']
# 2 .
# Sample Output: [['it', '<unk>', 'this', 'by', '<unk>', '<unk>', 'about', 'two', '<unk>', '.']]
# Predicted Output: ['the', 'way', 'of', 'the', '<unk>', '<unk>', 'two', '<unk>', '.']
# 3 .
# Sample Output: [['so', 'as', 'you', 'can', 'see', 'here', ',', 'this', 'is', 'a', ',', '<unk>', '<unk>', '<unk>', 'board', '.']]
# Predicted Output: ['and', 'you', 'can', 'see', 'here', 'is', 'the', '<unk>', '<unk>', '<unk>', '.']
# 4 .
# Sample Output: [['these', 'blocks', '<unk>', '<unk>', '.']]
# Predicted Output: ['this', 'is', 'the', '<unk>', '.']
# Time used for evaluate on dev set: 0 m 7 s
# Starting training epoch 4/10
# 240/240 [==============================] - 28s 117ms/step - loss: 1.1764 - accuracy: 0.4847
# Time used for epoch 4: 0 m 28 s
# Evaluating on dev set after epoch 4/10:
# Model BLEU score: 14.12
# 0 .
# Sample Output: [['there', 'are', 'four', '<unk>', '<unk>', 'that', ',', 'each', 'time', 'this', 'ring', '<unk>', 'it', ',', 'as', 'it', '<unk>', 'the', '<unk>', 'of', 'the', 'display', ',', 'it', '<unk>', 'up', 'a', 'position', 'signal', '.']]
# Predicted Output: ['there', '&apos;s', 'four', '<unk>', ',', 'to', 'every', 'single', '<unk>', ',', 'but', 'it', '&apos;s', '<unk>', 'to', 'the', '<unk>', ',', 'it', '&apos;s', '<unk>', '.']
# 1 .
# Sample Output: [['but', 'this', 'is', 'really', 'just', 'the', 'beginning', '.']]
# Predicted Output: ['but', 'this', 'is', 'just', 'the', 'beginning', '.']
# 2 .
# Sample Output: [['it', '<unk>', 'this', 'by', '<unk>', '<unk>', 'about', 'two', '<unk>', '.']]
# Predicted Output: ['the', 'way', 'it', '&apos;s', '<unk>', 'to', 'the', 'gray', 'one', '.']
# 3 .
# Sample Output: [['so', 'as', 'you', 'can', 'see', 'here', ',', 'this', 'is', 'a', ',', '<unk>', '<unk>', '<unk>', 'board', '.']]
# Predicted Output: ['and', 'so', 'you', 'can', 'see', 'here', 'is', 'the', '<unk>', '<unk>', '<unk>', '.']
# 4 .
# Sample Output: [['these', 'blocks', '<unk>', '<unk>', '.']]
# Predicted Output: ['this', 'is', 'probably', 'going', 'to', 'discover', '.']
# Time used for evaluate on dev set: 0 m 7 s
# Starting training epoch 5/10
# 240/240 [==============================] - 28s 116ms/step - loss: 1.0898 - accuracy: 0.5041
# Time used for epoch 5: 0 m 27 s
# Evaluating on dev set after epoch 5/10:
# Model BLEU score: 14.23
# 0 .
# Sample Output: [['there', 'are', 'four', '<unk>', '<unk>', 'that', ',', 'each', 'time', 'this', 'ring', '<unk>', 'it', ',', 'as', 'it', '<unk>', 'the', '<unk>', 'of', 'the', 'display', ',', 'it', '<unk>', 'up', 'a', 'position', 'signal', '.']]
# Predicted Output: ['there', 'are', 'four', '<unk>', ',', 'to', 'grab', 'each', 'other', ',', 'until', 'it', 'goes', 'back', 'in', 'this', '<unk>', ',', 'which', 'is', '<unk>', '<unk>', ',', 'which', 'is', '<unk>', '<unk>', '.']
# 1 .
# Sample Output: [['but', 'this', 'is', 'really', 'just', 'the', 'beginning', '.']]
# Predicted Output: ['but', 'this', 'is', 'just', 'the', 'beginning', '.']
# 2 .
# Sample Output: [['it', '<unk>', 'this', 'by', '<unk>', '<unk>', 'about', 'two', '<unk>', '.']]
# Predicted Output: ['it', '&apos;s', 'about', 'two', 'colors', 'around', 'the', 'axis', '.']
# 3 .
# Sample Output: [['so', 'as', 'you', 'can', 'see', 'here', ',', 'this', 'is', 'a', ',', '<unk>', '<unk>', '<unk>', 'board', '.']]
# Predicted Output: ['and', 'you', 'can', 'see', 'this', 'is', 'the', '<unk>', '<unk>', '<unk>', '<unk>', '.']
# 4 .
# Sample Output: [['these', 'blocks', '<unk>', '<unk>', '.']]
# Predicted Output: ['this', 'is', 'going', 'to', 'happen', '.']
# Time used for evaluate on dev set: 0 m 7 s
# Starting training epoch 6/10
# 240/240 [==============================] - 28s 118ms/step - loss: 1.0314 - accuracy: 0.5186
# Time used for epoch 6: 0 m 28 s
# Evaluating on dev set after epoch 6/10:
# Model BLEU score: 14.75
# 0 .
# Sample Output: [['there', 'are', 'four', '<unk>', '<unk>', 'that', ',', 'each', 'time', 'this', 'ring', '<unk>', 'it', ',', 'as', 'it', '<unk>', 'the', '<unk>', 'of', 'the', 'display', ',', 'it', '<unk>', 'up', 'a', 'position', 'signal', '.']]
# Predicted Output: ['there', 'are', 'four', '<unk>', ',', 'to', 'every', 'organization', ',', 'but', 'it', '&apos;s', 'when', 'it', '&apos;s', '<unk>', 'in', 'the', '<unk>', ',', 'it', '&apos;s', '<unk>', '.']
# 1 .
# Sample Output: [['but', 'this', 'is', 'really', 'just', 'the', 'beginning', '.']]
# Predicted Output: ['but', 'this', 'is', 'just', 'the', 'beginning', '.']
# 2 .
# Sample Output: [['it', '<unk>', 'this', 'by', '<unk>', '<unk>', 'about', 'two', '<unk>', '.']]
# Predicted Output: ['it', '&apos;s', 'covered', 'with', 'two', '<unk>', '.']
# 3 .
# Sample Output: [['so', 'as', 'you', 'can', 'see', 'here', ',', 'this', 'is', 'a', ',', '<unk>', '<unk>', '<unk>', 'board', '.']]
# Predicted Output: ['and', 'you', 'can', 'see', 'this', 'one', 'is', 'the', '<unk>', '<unk>', '<unk>', '.']
# 4 .
# Sample Output: [['these', 'blocks', '<unk>', '<unk>', '.']]
# Predicted Output: ['this', 'is', 'going', 'to', 'happen', '.']
# Time used for evaluate on dev set: 0 m 7 s
# Starting training epoch 7/10
# 240/240 [==============================] - 28s 115ms/step - loss: 0.9867 - accuracy: 0.5301
# Time used for epoch 7: 0 m 27 s
# Evaluating on dev set after epoch 7/10:
# Model BLEU score: 14.85
# 0 .
# Sample Output: [['there', 'are', 'four', '<unk>', '<unk>', 'that', ',', 'each', 'time', 'this', 'ring', '<unk>', 'it', ',', 'as', 'it', '<unk>', 'the', '<unk>', 'of', 'the', 'display', ',', 'it', '<unk>', 'up', 'a', 'position', 'signal', '.']]
# Predicted Output: ['there', '&apos;s', 'four', '<unk>', ',', 'to', 'every', '<unk>', ',', 'for', 'each', 'other', ',', 'when', 'it', 'came', 'over', 'when', 'it', 'was', 'in', 'the', '<unk>', ',', 'it', '&apos;s', '<unk>', '.']
# 1 .
# Sample Output: [['but', 'this', 'is', 'really', 'just', 'the', 'beginning', '.']]
# Predicted Output: ['but', 'this', 'is', 'just', 'the', 'beginning', '.']
# 2 .
# Sample Output: [['it', '<unk>', 'this', 'by', '<unk>', '<unk>', 'about', 'two', '<unk>', '.']]
# Predicted Output: ['the', 'way', 'of', 'the', '<unk>', 'comes', 'around', 'two', '<unk>', '.']
# 3 .
# Sample Output: [['so', 'as', 'you', 'can', 'see', 'here', ',', 'this', 'is', 'a', ',', '<unk>', '<unk>', '<unk>', 'board', '.']]
# Predicted Output: ['and', 'you', 'can', 'see', 'this', '<unk>', '<unk>', '<unk>', '<unk>', '<unk>', '.']
# 4 .
# Sample Output: [['these', 'blocks', '<unk>', '<unk>', '.']]
# Predicted Output: ['this', 'is', 'the', '<unk>', '.']
# Time used for evaluate on dev set: 0 m 7 s
# Starting training epoch 8/10
# 240/240 [==============================] - 28s 116ms/step - loss: 0.9520 - accuracy: 0.5398
# Time used for epoch 8: 0 m 28 s
# Evaluating on dev set after epoch 8/10:
# Model BLEU score: 14.93
# 0 .
# Sample Output: [['there', 'are', 'four', '<unk>', '<unk>', 'that', ',', 'each', 'time', 'this', 'ring', '<unk>', 'it', ',', 'as', 'it', '<unk>', 'the', '<unk>', 'of', 'the', 'display', ',', 'it', '<unk>', 'up', 'a', 'position', 'signal', '.']]
# Predicted Output: ['there', 'are', 'four', 'types', 'of', 'control', ',', 'for', 'each', 'other', ',', 'when', 'it', 'came', 'over', 'when', 'it', 'was', 'over', 'the', 'image', ',', 'it', '&apos;s', 'got', 'over', 'the', '<unk>', '.']
# 1 .
# Sample Output: [['but', 'this', 'is', 'really', 'just', 'the', 'beginning', '.']]
# Predicted Output: ['but', 'this', 'is', 'really', 'just', '<unk>', '.']
# 2 .
# Sample Output: [['it', '<unk>', 'this', 'by', '<unk>', '<unk>', 'about', 'two', '<unk>', '.']]
# Predicted Output: ['it', '&apos;s', 'been', 'done', 'by', '<unk>', '.']
# 3 .
# Sample Output: [['so', 'as', 'you', 'can', 'see', 'here', ',', 'this', 'is', 'a', ',', '<unk>', '<unk>', '<unk>', 'board', '.']]
# Predicted Output: ['and', 'you', 'can', 'see', 'here', 'this', 'is', 'the', '<unk>', '<unk>', '.']
# 4 .
# Sample Output: [['these', 'blocks', '<unk>', '<unk>', '.']]
# Predicted Output: ['this', 'can', 'show', 'up', '.']
# Time used for evaluate on dev set: 0 m 7 s
# Starting training epoch 9/10
# 240/240 [==============================] - 28s 115ms/step - loss: 0.9250 - accuracy: 0.5473
# Time used for epoch 9: 0 m 27 s
# Evaluating on dev set after epoch 9/10:
# Model BLEU score: 15.72
# 0 .
# Sample Output: [['there', 'are', 'four', '<unk>', '<unk>', 'that', ',', 'each', 'time', 'this', 'ring', '<unk>', 'it', ',', 'as', 'it', '<unk>', 'the', '<unk>', 'of', 'the', 'display', ',', 'it', '<unk>', 'up', 'a', 'position', 'signal', '.']]
# Predicted Output: ['there', 'are', 'four', '<unk>', ',', 'to', 'every', 'organization', ',', 'because', 'it', 'stops', 'the', '<unk>', ',', 'it', '&apos;s', '<unk>', '<unk>', 'to', 'the', '<unk>', '.']
# 1 .
# Sample Output: [['but', 'this', 'is', 'really', 'just', 'the', 'beginning', '.']]
# Predicted Output: ['but', 'this', 'is', 'just', 'the', 'real', 'experience', '.']
# 2 .
# Sample Output: [['it', '<unk>', 'this', 'by', '<unk>', '<unk>', 'about', 'two', '<unk>', '.']]
# Predicted Output: ['it', '&apos;s', 'been', 'done', 'by', 'the', 'two', 'two', '<unk>', '.']
# 3 .
# Sample Output: [['so', 'as', 'you', 'can', 'see', 'here', ',', 'this', 'is', 'a', ',', '<unk>', '<unk>', '<unk>', 'board', '.']]
# Predicted Output: ['and', 'you', 'can', 'see', 'this', 'is', 'the', '<unk>', '<unk>', '<unk>', 'ice', '<unk>', '.']
# 4 .
# Sample Output: [['these', 'blocks', '<unk>', '<unk>', '.']]
# Predicted Output: ['this', 'can', 'show', 'the', 'way', '.']
# Time used for evaluate on dev set: 0 m 7 s
# Starting training epoch 10/10
# 240/240 [==============================] - 28s 116ms/step - loss: 0.9003 - accuracy: 0.5546
# Time used for epoch 10: 0 m 27 s
# Evaluating on dev set after epoch 10/10:
# Model BLEU score: 15.32
# 0 .
# Sample Output: [['there', 'are', 'four', '<unk>', '<unk>', 'that', ',', 'each', 'time', 'this', 'ring', '<unk>', 'it', ',', 'as', 'it', '<unk>', 'the', '<unk>', 'of', 'the', 'display', ',', 'it', '<unk>', 'up', 'a', 'position', 'signal', '.']]
# Predicted Output: ['there', 'are', 'four', '<unk>', 'control', ',', 'to', 'each', 'other', ',', 'but', 'this', 'starts', '<unk>', ',', 'it', '&apos;s', 'a', '<unk>', '<unk>', '.']
# 1 .
# Sample Output: [['but', 'this', 'is', 'really', 'just', 'the', 'beginning', '.']]
# Predicted Output: ['but', 'this', 'is', 'really', 'just', 'the', 'beginning', '.']
# 2 .
# Sample Output: [['it', '<unk>', 'this', 'by', '<unk>', '<unk>', 'about', 'two', '<unk>', '.']]
# Predicted Output: ['the', 'way', 'it', 'comes', 'by', 'two', 'gray', '.']
# 3 .
# Sample Output: [['so', 'as', 'you', 'can', 'see', 'here', ',', 'this', 'is', 'a', ',', '<unk>', '<unk>', '<unk>', 'board', '.']]
# Predicted Output: ['and', 'you', 'can', 'see', 'here', ',', 'this', 'is', 'a', '<unk>', 'electrical', 'device', '.']
# 4 .
# Sample Output: [['these', 'blocks', '<unk>', '<unk>', '.']]
# Predicted Output: ['this', 'can', 'show', 'text', '.']
# Time used for evaluate on dev set: 0 m 7 s
# Training finished!
# Time used for training: 6 m 4 s
# Evaluating on test set:
# Model BLEU score: 15.23
# 0 .
# Sample Output: [['the', 'second', 'quote', 'is', 'from', 'the', 'head', 'of', 'the', 'u.k.', 'financial', 'services', '<unk>', '.']]
# Predicted Output: ['traffic', 'lights', 'ended', 'up', 'to', 'the', '<unk>', 'jellyfish', ',', '<unk>', 'funded', '.']
# 1 .
# Sample Output: [['it', 'gets', 'worse', '.']]
# Predicted Output: ['it', '&apos;s', 'worse', 'than', 'worse', '.']
# 2 .
# Sample Output: [['what', '&apos;s', 'happening', 'here', '?', 'how', 'can', 'this', 'be', 'possible', '?']]
# Predicted Output: ['what', 'is', 'happening', 'here', '?', 'what', 'is', 'this', '?']
# 3 .
# Sample Output: [['unfortunately', ',', 'the', 'answer', 'is', 'yes', '.']]
# Predicted Output: ['unfortunately', ',', 'the', 'answer', 'is', 'correct', '.']
# 4 .
# Sample Output: [['but', 'there', '&apos;s', 'an', '<unk>', 'solution', 'which', 'is', 'coming', 'from', 'what', 'is', 'known', 'as', 'the', 'science', 'of', '<unk>', '.']]
# Predicted Output: ['but', ',', 'there', '&apos;s', 'a', 'very', 'interesting', 'solution', 'to', 'be', 'a', 'very', 'interesting', 'problem', 'from', 'the', '<unk>', 'of', 'the', '<unk>', 'of', '<unk>', '.']
# Time used for evaluate on test set: 0 m 7 s
